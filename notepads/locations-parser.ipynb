# %% [markdown]
# # Location Parse

# %% [markdown]
# Retrieve locations near city
#
# *pip install requests*

# %%
import requests
import json

def get_locations(lat: float, lon: float, radius: int, amenity: str) -> dict:
    overpass_query = f"""
    [out:json];
    (
      node["amenity"="{amenity}"](around:{radius},{lat},{lon});
      way["amenity"="{amenity}"](around:{radius},{lat},{lon});
    );
    out center;
    """

    url = "https://overpass-api.de/api/interpreter"

    response = requests.post(
        url,
        data=overpass_query,
        headers={"Content-Type": "text/plain"}
    )

    response.raise_for_status()
    return response.json()

def parse_lcoations(data: dict) -> list:
    locations = []
    for element in data.get("elements", []):
        if "tags" in element:
            tags = element.get("tags", {})
            name = element["tags"].get("name", "Unnamed")
            website = tags.get("website") or tags.get("contact:website")

            lat = element.get("lat") or element.get("center", {}).get("lat")
            lon = element.get("lon") or element.get("center", {}).get("lon")
            locations.append({
                "name": name,
                "latitude": lat,
                "longitude": lon,
                "website": website
            })
    return locations

LAT = 48.2931
LON = 25.9296
RADIUS = 1000  # meters
AMENITY = "restaurant"

data = get_locations(LAT, LON, RADIUS, AMENITY)
print(json.dumps(data, indent=2)[:500])
locations = parse_lcoations(data)
print(locations)

print([l for l in locations if l["website"] != None])
# Out:
# {
#   "version": 0.6,
#   "generator": "Overpass API 0.7.62.8 e802775f",
#   "osm3s": {
#     "timestamp_osm_base": "2026-01-18T16:05:06Z",
#     "copyright": "The data included in this document is from www.openstreetmap.org. The data is made available under ODbL."
#   },
#   "elements": [
#     {
#       "type": "node",
#       "id": 943053314,
#       "lat": 48.2853985,
#       "lon": 25.934165,
#       "tags": {
#         "amenity": "restaurant",
#         "name": "\u0428\u0430\u0440\u043c",
#         "name:uk": "\u0428\u04
# [{'name': 'Шарм', 'latitude': 48.2853985, 'longitude': 25.934165, 'website': None}, {'name': 'Кнаус', 'latitude': 48.2932749, 'longitude': 25.9353508, 'website': None}, {'name': 'Квінто', 'latitude': 48.2911736, 'longitude': 25.936134, 'website': None}, {'name': 'Маестро', 'latitude': 48.28908, 'longitude': 25.9387663, 'website': 'www.maestro.cv.ua'}, {'name': 'Non Solo Pizza', 'latitude': 48.2915477, 'longitude': 25.9328578, 'website': None}, {'name': 'Ватра', 'latitude': 48.290881, 'longitude': 25.9361045, 'website': None}, {'name': 'Київ', 'latitude': 48.2896114, 'longitude': 25.9343379, 'website': None}, {'name': 'Хінкальня', 'latitude': 48.2915748, 'longitude': 25.9345536, 'website': None}, {'name': 'Пекін', 'latitude': 48.2949736, 'longitude': 25.9368762, 'website': None}, {'name': 'Сорбонна', 'latitude': 48.2936468, 'longitude': 25.9280297, 'website': None}, {'name': 'ZONE of Secret Kitchen', 'latitude': 48.2914847, 'longitude': 25.9318145, 'website': None}, {'name': 'Чернівчанка', 'latitude': 48.2900887, 'longitude': 25.9365843, 'website': None}, {'name': 'Винний погріб Граф Воронцов', 'latitude': 48.2960998, 'longitude': 25.9375507, 'website': None}, {'name': 'Francais', 'latitude': 48.2922161, 'longitude': 25.9383424, 'website': None}, {'name': 'Корчма Колесо', 'latitude': 48.2911439, 'longitude': 25.9356026, 'website': None}, {'name': 'Старе Місто', 'latitude': 48.2908194, 'longitude': 25.9340367, 'website': None}, {'name': 'Tomat Gold', 'latitude': 48.2917472, 'longitude': 25.9378771, 'website': None}, {'name': 'Шошо', 'latitude': 48.2927772, 'longitude': 25.9346826, 'website': 'https://www.foxtrot.com.ua/'}, {'name': 'Георг Палац', 'latitude': 48.297817, 'longitude': 25.9289162, 'website': None}, {'name': 'Жар-Птиця', 'latitude': 48.2940704, 'longitude': 25.9262036, 'website': None}, {'name': 'Рандеву', 'latitude': 48.291996, 'longitude': 25.9273843, 'website': None}, {'name': 'Кіото', 'latitude': 48.2895761, 'longitude': 25.9366289, 'website': None}, {'name': 'СанРемо', 'latitude': 48.2947662, 'longitude': 25.9269067, 'website': None}, {'name': 'Chocolate Fusion Cafe', 'latitude': 48.2930976, 'longitude': 25.9300076, 'website': None}, {'name': 'Unnamed', 'latitude': 48.2911814, 'longitude': 25.9342538, 'website': None}, {'name': 'Bier Platz', 'latitude': 48.2923241, 'longitude': 25.936572, 'website': None}, {'name': 'New York Street Pizza', 'latitude': 48.2900246, 'longitude': 25.9347709, 'website': 'https://pizza-nys.com.ua/'}, {'name': 'AllureInn', 'latitude': 48.2922691, 'longitude': 25.9359618, 'website': None}, {'name': 'Панська Гуральня', 'latitude': 48.2910234, 'longitude': 25.9360258, 'website': 'https://huralnia.com.ua'}, {'name': 'По Полам', 'latitude': 48.2927907, 'longitude': 25.9299331, 'website': None}, {'name': 'Гопачок', 'latitude': 48.2848022, 'longitude': 25.9329282, 'website': 'https://gopachok.choiceqr.com/'}, {'name': 'Йокі', 'latitude': 48.2921577, 'longitude': 25.9309703, 'website': None}, {'name': 'YOKI', 'latitude': 48.2921244, 'longitude': 25.9311528, 'website': 'https://yoki.ua/'}, {'name': 'Gorno', 'latitude': 48.2901719, 'longitude': 25.9362676, 'website': None}, {'name': 'Вавілон', 'latitude': 48.2885639, 'longitude': 25.9340274, 'website': None}, {'name': 'La Multi ani', 'latitude': 48.2944224, 'longitude': 25.9378972, 'website': None}, {'name': 'Сімейна веранда', 'latitude': 48.2909447, 'longitude': 25.9344357, 'website': None}, {'name': 'Ді Бокка', 'latitude': 48.2943184, 'longitude': 25.9341648, 'website': None}, {'name': 'Кафе ЕКВАТОР', 'latitude': 48.2978308, 'longitude': 25.9291313, 'website': None}, {'name': 'Мята', 'latitude': 48.2867768, 'longitude': 25.9389688, 'website': 'https://mintchernivtsi.business.site/'}, {'name': 'Cher Ami', 'latitude': 48.2930804, 'longitude': 25.9312188, 'website': None}, {'name': 'Етно-ресторан Колесо', 'latitude': 48.291236, 'longitude': 25.9354142, 'website': None}, {'name': 'Хелен', 'latitude': 48.297289, 'longitude': 25.9366952, 'website':  ...

# %%
from math import radians, sin, cos, sqrt, atan2, degrees

def reverse_geocode(location: dict) -> dict:
    url = "https://nominatim.openstreetmap.org/reverse"
    params = {
        "lat": location["latitude"],
        "lon": location["longitude"],
        "format": "jsonv2",
        "addressdetails": 1
    }

    headers = {
        "User-Agent": "geo-demo-app (va.melnyk@chnu.edu.ua)"
    }

    r = requests.get(url, params=params, headers=headers, timeout=10)
    r.raise_for_status()

    data = r.json()
    address = data.get("address", {})

    location["street"] = address.get("road")
    location["house_number"] = address.get("house_number")
    location["city"] = address.get("city") or address.get("town")
    location["address"] = data.get("display_name")
    return location

def haversine_distance(lat1, lon1, lat2, lon2):
    R = 6371000  # Earth radius in meters

    dlat = radians(lat2 - lat1)
    dlon = radians(lon2 - lon1)

    a = (
        sin(dlat / 2) ** 2
        + cos(radians(lat1))
        * cos(radians(lat2))
        * sin(dlon / 2) ** 2
    )

    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    return R * c

def calculate_bearing(lat1, lon1, lat2, lon2):
    lat1 = radians(lat1)
    lat2 = radians(lat2)
    dlon = radians(lon2 - lon1)

    x = sin(dlon) * cos(lat2)
    y = cos(lat1) * sin(lat2) - sin(lat1) * cos(lat2) * cos(dlon)

    bearing = (degrees(atan2(x, y)) + 360) % 360
    return bearing

def bearing_to_direction(bearing):
    directions = [
        "north",
        "north-east",
        "east",
        "south-east",
        "south",
        "south-west",
        "west",
        "north-west"
    ]

    index = round(bearing / 45) % 8
    return directions[index]

location = reverse_geocode(locations[1])
location["distance"] = haversine_distance(LAT, LON, location["latitude"], location["longitude"])
bearing = calculate_bearing(LAT, LON, location["latitude"], location["longitude"])
location["direction"] = bearing_to_direction(bearing)
print(location)
# Out:
# {'name': 'Кнаус', 'latitude': 48.2932749, 'longitude': 25.9353508, 'website': None, 'street': 'Центральна площа', 'house_number': None, 'city': 'Чернівці', 'address': 'Кнаус, Центральна площа, Старе Місто, Чернівці, Чернівецька міська громада, Чернівецький район, Чернівецька область, 58002, Україна', 'distance': 425.8890974895354, 'direction': 'east'}

# %% [markdown]
# ### Next
# 1. Retrieve menus for given locations (?)
# 2. Menus for rag vectorization + pipeline
# 3.
#
#
# Сорбонна
# піца іжа напої
#
# lat lon, distance <- overpass
